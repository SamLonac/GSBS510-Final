# %% [raw]
# ---
# self-contained: true
# title: "MCU Data Wrangling"
# format:
#   html:
#     theme: simplex
# author: "Samuel Lonac"
# ---

# %% [markdown]
# ## MCU Data Wrangling

# %%
import pandas as pd
import numpy as np

# %%
# Read in datasets

mcu1 = pd.read_csv("mcu dataset.csv")

mcu2 = pd.read_csv("mcu_box_office.csv")

# %%
mcu1.head()
# Out:
#                                  Name US release Date         Director  \
# 0                            Iron Man     May 2, 2008      Jon Favreau
# 1                 The incredible Hulk   June 13, 2008  Louis Leterrier
# 2                          Iron Man 2     May 7, 2010      Jon Favreau
# 3                                Thor     May 6, 2011  Kenneth Branagh
# 4  Captain America: The first Avenger   July 22, 2011     Joe Jhonston
#
#                                   Producer  Duration  \
# 0                 Avi Arad and Kevin Feige   2h 6min
# 1  Avi Arad ,Gale Ann Hurd and Kevin Feige  1h 52min
# 2                              Kevin Feige   2h 4min
# 3                              Kevin Feige  1h 55min
# 4                              Kevin Feige   2h 4min
#
#                          Genre  IMDB rating  metascore  \
# 0   Action , Adventure, Sci-Fi          7.9         79
# 1   Action , Adventure, Sci-Fi          6.6         61
# 2   Action , Adventure, Sci-Fi          7.0         57
# 3  Action , Adventure, Fantasy          7.0         57
# 4   Action , Adventure, Sci-Fi          6.9         66
#
#                                                 Cast        Budget  \
# 0  Robert Downey Jr. , Gweneth Paltrow , Terrence...  $140,000,000
# 1               Edward Norton , Liv Tyler , Tim Roth  $150,000,000
# 2  Robert Downey Jr. , Gweneth Paltrow , Mickey R...  $200,000,000
# 3  Chris Hemsworth , Anthony Hopkins , Natalie Po...  $150,000,000
# 4    Chris Evans ,  Hugo Weaving , Samuel L. Jackson  $140,000,000
#
#   Domestic Gross   Total Gross Opening Gross  Oscar Nomination  Oscar won  \
# 0   $318,604,126  $585,366,247   $98,618,668                 2          0
# 1   $134,806,913  $264,770,996   $55,414,050                 0          0
# 2   $312,433,331  $623,933,331  $128,122,480                 1          0
# 3   $181,030,624  $449,326,618   $65,723,338                 0          0
# 4   $176,654,505  $370,569,774   $65,058,524                 0          0
#
#    Phase
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
mcu2.head()
# Out:
#                           movie_title  mcu_phase release_date  tomato_meter  \
# 0                            Iron Man          1     5/2/2008            94
# 1                 The Incredible Hulk          1    6/13/2008            67
# 2                          Iron Man 2          1     5/7/2010            72
# 3                                Thor          1     5/6/2011            77
# 4  Captain America: The First Avenger          1    7/22/2011            79
#
#    audience_score  movie_duration production_budget opening_weekend  \
# 0              91             126       186,000,000     102,118,668
# 1              70             112       137,500,000      55,414,050
# 2              71             124       170,000,000     128,122,480
# 3              76             113       150,000,000      65,723,338
# 4              75             124       140,000,000      65,058,524
#
#   domestic_box_office worldwide_box_office
# 0         318,604,126          585,171,547
# 1         134,806,913          265,573,859
# 2         312,433,331          621,156,389
# 3         181,030,624          449,326,618
# 4         176,654,505          370,569,776

# %%
# prompt: transform mcu1['US release Date'] and mcu2['release_date'] to date time variables in the same format

mcu1['US release Date'] = pd.to_datetime(mcu1['US release Date'], format='%B %d, %Y')
mcu2['release_date'] = pd.to_datetime(mcu2['release_date'])

# %%
pd.options.display.max_columns = None

# %%
# Right join mcu1 and mcu2 on US release Date = release_date

mcu_combined = pd.merge(right=mcu2, left=mcu1, left_on='US release Date', right_on='release_date', how='right')

# %%
# Reorder and drop unnecessary columns

mcu_combined = mcu_combined[['Name', 'US release Date', 'mcu_phase', 'Director', 'Producer', 'Cast', 'Genre', 'movie_duration', 'IMDB rating', 'metascore', 'tomato_meter', 'audience_score', 'Oscar Nomination', 'Oscar won', 'production_budget', 'opening_weekend', 'domestic_box_office', 'worldwide_box_office']]

# %%
# Drop rows 23 through 26 of mcu_combined

mcu_combined = mcu_combined.drop(np.arange(23, 27), axis=0)

# %%
mcu3 = pd.read_csv("mcu_additional_movies.csv")
mcu3['US release Date'] = pd.to_datetime(mcu3['US release Date'])
mcu3.head()
# Out:
#                                           Name US release Date  mcu_phase  \
# 0                                  Black Widow      2021-07-09          4
# 1    Shang-Chi and the Legend of the Ten Rings      2021-09-03          4
# 2                                     Eternals      2021-11-05          4
# 3                      Spider-Man: No Way Home      2021-12-17          4
# 4  Doctor Strange in the Multiverse of Madness      2022-05-06          4
#
#                 Director                           Producer  \
# 0         Cate Shortland                        Kevin Feige
# 1  Destin Daniel Cretton  Kevin Feige and Jonathan Schwartz
# 2             Chloe Zhao         Kevin Feige and Nate Moore
# 3              Jon Watts         Kevin Feige and Amy Pascal
# 4              Sam Raimi                        Kevin Feige
#
#                                                 Cast  \
# 0  Scarlett Johansson , Florence Pugh , David Har...
# 1  Simu Liu , Awkwafina , Tony Leung Chiu-wai , B...
# 2  Gemma Chan , Richard Madden , Angelina Jolie ,...
# 3  Tom Holland , Zendaya , Benedict Cumberbatch ,...
# 4  Benedict Cumberbatch , Elizabeth Olsen , Chisw...
#
#                                              Genre  movie_duration  \
# 0                     Action , Adventure , Sci-Fi              133
# 1           Action , Adventure , Fantasy , Sci-Fi              133
# 2           Action , Adventure , Fantasy , Sci-Fi              157
# 3           Action , Adventure , Fantasy , Sci-Fi              148
# 4  Action , Adventure , Fantasy , Horror , Sci-Fi              126
#
#    IMDB rating  metascore  tomato_meter  audience_score  Oscar Nomination  \
# 0          6.7         68            79              91                 0
# 1          7.4         71            92              98                 1
# 2          6.3         52            47              78                 0
# 3          8.2         71            93              98                 3
# 4          6.9         60            73              85                 0
#
#    Oscar won production_budget opening_weekend domestic_box_office  \
# 0          0       200,000,000      80,366,312         183,651,655
# 1          0       150,000,000      75,388,688         224,543,292
# 2          0       200,000,000      71,297,219         164,870,264
# 3          0       200,000,000     260,138,569         803,975,784
# 4          0       294,500,000     187,420,998         411,331,607
#
#   worldwide_box_office
# 0          379,751,655
# 1          432,243,292
# 2          402,064,929
# 3        1,891,108,035
# 4          955,775,804

# %%
# Append mcu3 to mcu_combined using pandas.concat and reset index

mcu_combined = pd.concat([mcu_combined, mcu3], ignore_index=True)

# %%
# Create percentage metrics for movie ratings

mcu_combined['IMDB rating %'] = mcu_combined['IMDB rating']/10
mcu_combined['metascore %'] = mcu_combined['metascore']/100
mcu_combined['tomato_meter %'] = mcu_combined['tomato_meter']/100
mcu_combined['audience_score %'] = mcu_combined['audience_score']/100

# %%
# Dummify Cast variable
# Step 1: Split the 'Cast' column into a list of actors
mcu_combined['Cast_List'] = mcu_combined['Cast'].str.split(',')

# Step 2: Use pandas' get_dummies to create dummy variables for each actor across all movies
# First explode the 'Cast_List' to separate rows for each actor per movie,
# and then using get_dummies to create binary indicators
cast_dummies = mcu_combined.explode('Cast_List')['Cast_List'].str.strip().str.get_dummies().groupby(level=0).sum()

# Merging the dummy variables back to the original dataset, ensuring we don't duplicate movie rows
mcu_combined = mcu_combined.join(cast_dummies)

# %%
# Dummify Genre variable
mcu_combined['Genre'] = mcu_combined['Genre'].str.split(',')

genre_dummies = mcu_combined.explode('Genre')['Genre'].str.strip().str.get_dummies().groupby(level=0).sum()

mcu_combined = mcu_combined.join(genre_dummies)

# %%
# prompt: drop cast, cast_list and genre

mcu_combined = mcu_combined.drop(columns=['Cast', 'Cast_List', 'Genre'])

# %%
# Create new row "Time Since Last Release" that is the datediff between the "US release Date" and the row above's "US release Date"

import datetime as dt
import pandas as pd

def diff_in_dates(df, date_column):
  """
  Calculates the difference in days between each row's date and the previous row's date.

  Args:
      df (pd.DataFrame): DataFrame containing the date column.
      date_column (str): Name of the date column.

  Returns:
      pd.Series: Series containing the time difference in days for each row.
  """
  time_since_last_release = []
  for i in range(len(df)):
    if i == 0:
      time_since_last_release.append(0)
    else:
      current_date = df[date_column].iloc[i]
      previous_date = df[date_column].iloc[i-1]
      diff = current_date - previous_date
      time_since_last_release.append(diff.days)
  return pd.Series(time_since_last_release)

# Apply the function to the DataFrame
mcu_combined["Time Since Last Release"] = diff_in_dates(mcu_combined, "US release Date")

# %%
# download mcu_combined to csv

mcu_combined.to_csv('mcu_combined.csv', index=False)
